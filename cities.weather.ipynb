# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import openweathermapy as ow
import pandas as pd

api_key = "362d2ce77ac1347c707f15a319677c99"

# %%
# Create a settings object with your API key and preferred units
settings = {"units": "metric", "appid": api_key}

# %%
# Get data for each city in cities.csv
weather_data = []
with open("../Resources/cities.csv") as cities_file:
    cities_reader = csv.reader(cities_file)
    header = next(cities_reader)
    print(header)
    cities = [(row[0], row[1]) for row in cities_reader]
    weather_data = [ow.get_current(row[0], **settings) for row in cities]
    #state
    print(cities)
# Out:
# ['city', 'state', 'country']
# [('New York', ' NY'), ('San Francisco', ' CA'), ('Honolulu', ' HI'), ('Anchorage', ' AK'), ('Brooklyn', ' NY'), ('Washington', ' DC'), ('Santa Rosa', ' CA'), ('Charleston', ' SC'), ('Bellevue', ' WA'), ('Seattle', ' WA'), ('Berkeley', ' CA'), ('Jersey City', ' NJ'), ('Oakland', ' CA'), ('Boston', ' MA'), ('Hartford', ' CT'), ('Albany', ' NY'), ('Philadelphia', ' PA'), ('Irvine', ' CA'), ('Long Beach', ' CA'), ('Los Angeles', ' CA'), ('Chicago', ' IL'), ('Boulder', ' CO'), ('San Jose', ' CA'), ('Burlington', ' VT'), ('Pittsburgh', ' PA'), ('Miami', ' FL'), ('Santa Barbara', ' CA'), ('Sacramento', ' CA'), ('Portland', ' ME'), ('West Palm Beach', ' FL'), ('Everett', ' WA'), ('Tacoma', ' WA'), ('Portland', ' OR'), ('Baltimore', ' MD'), ('New Orleans', ' LA'), ('Charlotte', ' NC'), ('Minneapolis', ' MN'), ('Eugene', ' OR'), ('San Diego', ' CA'), ('Bellingham', ' WA'), ('Atlanta', ' GA'), ('Denver', ' CO'), ('Saint Paul', ' MN'), ('Birmingham', ' AL'), ('Asheville', ' NC'), ('Fort Myers', ' FL'), ('Indianapolis', ' IN'), ('Jacksonville', ' FL'), ('Buffalo', ' NY'), ('Olympia', ' WA'), ('Saint Petersburg', ' FL'), ('Austin', ' TX'), ('Rochester', ' NY'), ('Orlando', ' FL'), ('Peoria', ' IL'), ('Cleveland', ' OH'), ('Raleigh', ' NC'), ('Arlington', ' TX'), ('Saint Louis', ' MO'), ('Milwaukee', ' WI'), ('Nashville', ' TN'), ('Tampa', ' FL'), ('Virginia Beach', ' VA'), ('Syracuse', ' NY'), ('Tallahassee', ' FL'), ('Bakersfield', ' CA'), ('Ann Arbor', ' MI'), ('Las Vegas', ' NV'), ('Columbus', ' OH'), ('Spokane', ' WA'), ('Memphis', ' TN'), ('Columbia', ' SC'), ('Salem', ' OR'), ('Fort Wayne', ' IN'), ('Dayton', ' OH'), ('Kansas City', ' MO'), ('Fort Worth', ' TX'), ('Fayetteville', ' AR'), ('Richmond', ' VA'), ('Greensboro', ' NC'), ('Dallas', ' TX'), ('Albuquerque', ' NM'), ('Phoenix', ' AZ'), ('Gainesville', ' FL'), ('Grand Rapids', ' MI'), ('Tucson', ' AZ'), ('Madison', ' WI'), ('Chattanooga', ' TN'), ('Fresno', ' CA'), ('Wichita', ' KS'), ('Salt Lake City', ' UT'), ('Detroit', ' MI'), ('Tulsa', ' OK'), ('Cincinnati', ' OH'), ('Lubbock', ' TX'), ('Des Moines', ' IA'), ('Houston', ' TX'), ('Oklahoma City', ' OK'), ('Knoxville', ' TN'), ('Springfield', ' MO'), ('Vancouver', ' WA'), ('Toledo', ' OH'), ('Little Rock', ' AR'), ('Louisville', ' KY'), ('Reno', ' NV'), ('Huntsville', ' AL'), ('Lexington', ' KY'), ('Boise', ' ID'), ('El Paso', ' TX'), ('San Antonio', ' TX')]

# %%
weather_data
# Out:
# [{'coord': {'lon': -73.99, 'lat': 40.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 31.79,
#    'pressure': 1016,
#    'humidity': 43,
#    'temp_min': 29.44,
#    'temp_max': 33.89},
#   'visibility': 16093,
#   'wind': {'speed': 2.6, 'deg': 320},
#   'clouds': {'all': 1},
#   'dt': 1561827223,
#   'sys': {'type': 1,
#    'id': 4686,
#    'message': 0.0142,
#    'country': 'US',
#    'sunrise': 1561800440,
#    'sunset': 1561854671},
#   'timezone': -14400,
#   'id': 5128581,
#   'name': 'New York',
#   'cod': 200},
#  {'coord': {'lon': -76.88, 'lat': 1.17},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 23,
#    'pressure': 1021,
#    'humidity': 43,
#    'temp_min': 23,
#    'temp_max': 23},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 140, 'gust': 12.3},
#   'clouds': {'all': 75},
#   'dt': 1561827114,
#   'sys': {'type': 1,
#    'id': 8592,
#    'message': 0.0058,
#    'country': 'CO',
#    'sunrise': 1561806312,
#    'sunset': 1561850187},
#   'timezone': -18000,
#   'id': 3669881,
#   'name': 'San Francisco',
#   'cod': 200},
#  {'coord': {'lon': -157.86, 'lat': 21.3},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 24.56,
#    'pressure': 1015,
#    'humidity': 78,
#    'temp_min': 22.78,
#    'temp_max': 26.11},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 90},
#   'clouds': {'all': 40},
#   'dt': 1561827375,
#   'sys': {'type': 1,
#    'id': 7878,
#    'message': 0.0071,
#    'country': 'US',
#    'sunrise': 1561823540,
#    'sunset': 1561871834},
#   'timezone': -36000,
#   'id': 5856195,
#   'name': 'Honolulu',
#   'cod': 200},
#  {'coord': {'lon': -149.89, 'lat': 61.22},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 19.26,
#    'pressure': 1021,
#    'humidity': 60,
#    'temp_min': 17,
#    'temp_max': 21.11},
#   'visibility': 3219,
#   'wind': {'speed': 1.23, 'deg': 220.733},
#   'clouds': {'all': 20},
#   'dt': 1561827375,
#   'sys': {'type': 1,
#    'id': 7759,
#    'message': 0.0115,
#    'country': 'US',
#    'sunrise': 1561811100,
#    'sunset': 1561880447},
#   'timezone': -28800,
#   'id': 5879400,
#   'name': 'Anchorage',
#   'cod': 200},
#  {'coord': {'lon': -81.74, 'lat': 41.44},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 29.25,
#    'pressure': 1020,
#    'humidity': 54,
#    'temp_min': 26.67,
#    'temp_max': 31.67},
#   'visibility': 16093,
#   'wind': {'speed': 6.2, 'deg': 270, 'gust': 8.7},
#   'clouds': {'all': 40},
#   'dt': 1561827305,
#   'sys': {'type': 1,
#    'id': 5396,
#    'message': 0.0091,
#    'country': 'US',
#    'sunrise': 1561802157,
#    'sunset': 1561856675},
#   'timezone': -14400,
#   'id': 5148346,
#   'name': 'Brooklyn',
#   'cod': 200},
#  {'coord': {'lon': -77.04, 'lat': 38.9},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 33.02,
#    'pressure': 1018,
#    'humidity': 52,
#    'temp_min': 31.11,
#    'temp_max': 34.44},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 350, 'gust': 7.7},
#   'clouds': {'all': 40},
#   'dt': 1561827135,
#   'sys': {'type': 1,
#    'id': 3614,
#    'message': 0.0133,
#    'country': 'US',
#    'sunrise': 1561801525,
#    'sunset': 1561855050},
#   'timezone': -14400,
#   'id': 4366164,
#   'name': 'Washington DC.',
#   'cod': 200},
#  {'coord': {'lon': -64.29, 'lat': -36.62},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 9.08,
#    'pressure': 1013.47,
#    'humidity': 74,
#    'temp_min': 9.08,
#    'temp_max': 9.08,
#    'sea_level': 1013.47,
#    'grnd_level': 988.17},
#   'wind': {'speed': 2.98, 'deg': 162.228},
#   'rain': {'3h': 0.125},
#   'clouds': {'all': 95},
#   'dt': 1561827375,
#   'sys': {'message': 0.0069,
#    'country': 'AR',
#    'sunrise': 1561807809,
#    'sunset': 1561842646},
#   'timezone': -10800,
#   'id': 3835994,
#   'name': 'Santa Rosa',
#   'cod': 200},
#  {'coord': {'lon': -79.94, 'lat': 32.79},
#   'weather': [{'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'},
#    {'id': 301, 'main': 'Drizzle', 'description': 'drizzle', 'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 30.12,
#    'pressure': 1022,
#    'humidity': 83,
#    'temp_min': 27,
#    'temp_max': 32.78},
#   'visibility': 14484,
#   'wind': {'speed': 3.1, 'deg': 70},
#   'clouds': {'all': 75},
#   'dt': 1561827365,
#   'sys': {'type': 1,
#    'id': 4627,
#    'message': 0.0075,
#    'country': 'US',
#    'sunrise': 1561803262,
#    'sunset': 1561854706},
#   'timezone': -14400,
#   'id': 4574324,
#   'name': 'Charleston',
#   'cod': 200},
#  {'coord': {'lon': 10.19, 'lat': 50.05},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 29.43,
#    'pressure': 1019,
#    'humidity': 21,
#    'temp_min': 24.44,
#    'temp_max': 32},
#   'visibility': 10000,
#   'wind': {'speed': 1.52, 'deg': 5.669},
#   'clouds': {'all': 1},
#   'dt': 1561827376,
#   'sys': {'type': 1,
#    'id': 1838,
#    'message': 0.0076,
#    'country': 'DE',
#    'sunrise': 1561777948,
#    'sunset': 1561836751},
#   'timezone': 7200,
#   'id': 2819564,
#   'name': 'Bellevue',
#   'cod': 200},
#  {'coord': {'lon': -122.33, 'lat': 47.6},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.45,
#    'pressure': 1022,
#    'humidity': 67,
#    'temp_min': 15.56,
#    'temp_max': 19.44},
#   'visibility': 16093,
#   'wind': {'speed': 1.72, 'deg': 2.661},
#   'clouds': {'all': 1},
#   'dt': 1561826875,
#   'sys': {'type': 1,
#    'id': 3417,
#    'message': 0.0121,
#    'country': 'US',
#    'sunrise': 1561810464,
#    'sunset': 1561867853},
#   'timezone': -25200,
#   'id': 5809844,
#   'name': 'Seattle',
#   'cod': 200},
#  {'coord': {'lon': -122.27, 'lat': 37.87},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 18.24,
#    'pressure': 1018,
#    'humidity': 72,
#    'temp_min': 13.89,
#    'temp_max': 21.67},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 260},
#   'clouds': {'all': 40},
#   'dt': 1561827260,
#   'sys': {'type': 1,
#    'id': 5154,
#    'message': 0.0111,
#    'country': 'US',
#    'sunrise': 1561812573,
#    'sunset': 1561865715},
#   'timezone': -25200,
#   'id': 5327684,
#   'name': 'Berkeley',
#   'cod': 200},
#  {'coord': {'lon': -74.08, 'lat': 40.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 31.84,
#    'pressure': 1014,
#    'humidity': 36,
#    'temp_min': 29.44,
#    'temp_max': 33.89},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 310},
#   'clouds': {'all': 1},
#   'dt': 1561827376,
#   'sys': {'type': 1,
#    'id': 6015,
#    'message': 0.0158,
#    'country': 'US',
#    'sunrise': 1561800461,
#    'sunset': 1561854693},
#   'timezone': -14400,
#   'id': 5099836,
#   'name': 'Jersey City',
#   'cod': 200},
#  {'coord': {'lon': -122.27, 'lat': 37.8},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 17.85,
#    'pressure': 1018,
#    'humidity': 72,
#    'temp_min': 13.89,
#    'temp_max': 21.67},
#   'visibility': 16093,
#   'wind': {'speed': 1.5},
#   'clouds': {'all': 20},
#   'dt': 1561827334,
#   'sys': {'type': 1,
#    'id': 5903,
#    'message': 0.0099,
#    'country': 'US',
#    'sunrise': 1561812586,
#    'sunset': 1561865703},
#   'timezone': -25200,
#   'id': 5378538,
#   'name': 'Oakland',
#   'cod': 200},
#  {'coord': {'lon': -71.06, 'lat': 42.36},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 25.99,
#    'pressure': 1014,
#    'humidity': 65,
#    'temp_min': 24,
#    'temp_max': 27.78},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 190},
#   'clouds': {'all': 90},
#   'dt': 1561827139,
#   'sys': {'type': 1,
#    'id': 3486,
#    'message': 0.0106,
#    'country': 'US',
#    'sunrise': 1561799401,
#    'sunset': 1561854304},
#   'timezone': -14400,
#   'id': 4930956,
#   'name': 'Boston',
#   'cod': 200},
#  {'coord': {'lon': -72.69, 'lat': 41.76},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 28.01,
#    'pressure': 1015,
#    'humidity': 62,
#    'temp_min': 25.56,
#    'temp_max': 30.56},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 240},
#   'clouds': {'all': 20},
#   'dt': 1561827197,
#   'sys': {'type': 1,
#    'id': 5878,
#    'message': 0.0152,
#    'country': 'US',
#    'sunrise': 1561799918,
#    'sunset': 1561854569},
#   'timezone': -14400,
#   'id': 4835797,
#   'name': 'Hartford',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 25.25,
#    'pressure': 1016,
#    'humidity': 78,
#    'temp_min': 22.78,
#    'temp_max': 27.78},
#   'visibility': 16093,
#   'wind': {'speed': 4.6, 'deg': 270},
#   'clouds': {'all': 40},
#   'dt': 1561827189,
#   'sys': {'type': 1,
#    'id': 5137,
#    'message': 0.0135,
#    'country': 'US',
#    'sunrise': 1561799985,
#    'sunset': 1561855011},
#   'timezone': -14400,
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': -75.16, 'lat': 39.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 32.17,
#    'pressure': 1017,
#    'humidity': 43,
#    'temp_min': 30,
#    'temp_max': 34.44},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 280},
#   'clouds': {'all': 1},
#   'dt': 1561827343,
#   'sys': {'type': 1,
#    'id': 5209,
#    'message': 0.0103,
#    'country': 'US',
#    'sunrise': 1561800874,
#    'sunset': 1561854799},
#   'timezone': -14400,
#   'id': 4560349,
#   'name': 'Philadelphia',
#   'cod': 200},
#  {'coord': {'lon': -117.83, 'lat': 33.69},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 22.77,
#    'pressure': 1017,
#    'humidity': 46,
#    'temp_min': 20,
#    'temp_max': 25.56},
#   'visibility': 12874,
#   'wind': {'speed': 2.43, 'deg': 201.723},
#   'clouds': {'all': 1},
#   'dt': 1561827256,
#   'sys': {'type': 1,
#    'id': 3578,
#    'message': 0.0138,
#    'country': 'US',
#    'sunrise': 1561812216,
#    'sunset': 1561863941},
#   'timezone': -25200,
#   'id': 5359777,
#   'name': 'Irvine',
#   'cod': 200},
#  {'coord': {'lon': -89.15, 'lat': 30.35},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 29.04,
#    'pressure': 1019,
#    'humidity': 69,
#    'temp_min': 26.67,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 40},
#   'clouds': {'all': 1},
#   'dt': 1561827376,
#   'sys': {'type': 1,
#    'id': 4248,
#    'message': 0.0087,
#    'country': 'US',
#    'sunrise': 1561805841,
#    'sunset': 1561856548},
#   'timezone': -18000,
#   'id': 4434069,
#   'name': 'Long Beach',
#   'cod': 200},
#  {'coord': {'lon': -118.24, 'lat': 34.05},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 22.84,
#    'pressure': 1016,
#    'humidity': 68,
#    'temp_min': 20,
#    'temp_max': 26.11},
#   'visibility': 14484,
#   'wind': {'speed': 2.95, 'deg': 201.7},
#   'clouds': {'all': 1},
#   'dt': 1561827086,
#   'sys': {'type': 1,
#    'id': 3694,
#    'message': 0.0159,
#    'country': 'US',
#    'sunrise': 1561812257,
#    'sunset': 1561864097},
#   'timezone': -25200,
#   'id': 5368361,
#   'name': 'Los Angeles',
#   'cod': 200},
#  {'coord': {'lon': -87.62, 'lat': 41.88},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 29.52,
#    'pressure': 1020,
#    'humidity': 74,
#    'temp_min': 25.56,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 1.17, 'deg': 24.342},
#   'clouds': {'all': 20},
#   'dt': 1561827087,
#   'sys': {'type': 1,
#    'id': 4309,
#    'message': 0.0121,
#    'country': 'US',
#    'sunrise': 1561803477,
#    'sunset': 1561858177},
#   'timezone': -18000,
#   'id': 4887398,
#   'name': 'Chicago',
#   'cod': 200},
#  {'coord': {'lon': -105.27, 'lat': 40.02},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 29.52,
#    'pressure': 1023,
#    'humidity': 27,
#    'temp_min': 23.89,
#    'temp_max': 34.44},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 350},
#   'clouds': {'all': 1},
#   'dt': 1561827173,
#   'sys': {'type': 1,
#    'id': 3958,
#    'message': 0.0131,
#    'country': 'US',
#    'sunrise': 1561808089,
#    'sunset': 1561862038},
#   'timezone': -21600,
#   'id': 5574991,
#   'name': 'Boulder',
#   'cod': 200},
#  {'coord': {'lon': -87.96, 'lat': 14.25},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 26,
#    'pressure': 1018,
#    'humidity': 69,
#    'temp_min': 26,
#    'temp_max': 26},
#   'visibility': 9000,
#   'wind': {'speed': 6.7, 'deg': 360},
#   'clouds': {'all': 40},
#   'dt': 1561827377,
#   'sys': {'type': 1,
#    'id': 7095,
#    'message': 0.0077,
#    'country': 'HN',
#    'sunrise': 1561807581,
#    'sunset': 1561854236},
#   'timezone': -21600,
#   'id': 3602137,
#   'name': 'San Jose',
#   'cod': 200},
#  {'coord': {'lon': -79.8, 'lat': 43.32},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 26.3,
#    'pressure': 1017,
#    'humidity': 74,
#    'temp_min': 24.44,
#    'temp_max': 28.33},
#   'visibility': 24140,
#   'wind': {'speed': 2.1, 'deg': 270},
#   'clouds': {'all': 75},
#   'dt': 1561827377,
#   'sys': {'type': 1,
#    'id': 818,
#    'message': 0.0068,
#    'country': 'CA',
#    'sunrise': 1561801291,
#    'sunset': 1561856609},
#   'timezone': -14400,
#   'id': 5911592,
#   'name': 'Burlington',
#   'cod': 200},
#  {'coord': {'lon': -79.99, 'lat': 40.44},
#   'weather': [{'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'}],
#   'base': 'stations',
#   'main': {'temp': 29.2,
#    'pressure': 1020,
#    'humidity': 69,
#    'temp_min': 26.11,
#    'temp_max': 31.67},
#   'visibility': 16093,
#   'wind': {'speed': 2.1},
#   'clouds': {'all': 90},
#   'dt': 1561827377,
#   'sys': {'type': 1,
#    'id': 3511,
#    'message': 0.0117,
#    'country': 'US',
#    'sunrise': 1561801938,
#    'sunset': 1561856054},
#   'timezone': -14400,
#   'id': 5206379,
#   'name': 'Pittsburgh',
#   'cod': 200},
#  {'coord': {'lon': -80.19, 'lat': 25.77},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'},
#    {'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 24.74,
#    'pressure': 1021,
#    'humidity': 88,
#    'temp_min': 24,
#    'temp_max': 26.67},
#   'visibility': 9656,
#   'wind': {'speed': 5.1, 'deg': 130},
#   'rain': {'1h': 2.46},
#   'clouds': {'all': 75},
#   'dt': 1561827147,
#   'sys': {'type': 1,
#    'id': 4110,
#    'message': 0.0081,
#    'country': 'US',
#    'sunrise': 1561804327,
#    'sunset': 1561853761},
#   'timezone': -14400,
#   'id': 4164138,
#   'name': 'Miami',
#   'cod': 200},
#  {'coord': {'lon': -119.7, 'lat': 34.42},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 22.3,
#    'pressure': 1016,
#    'humidity': 72,
#    'temp_min': 16,
#    'temp_max': 27.22},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1561827087,
#   'sys': {'type': 1,
#    'id': 4558,
#    'message': 0.008,
#    'country': 'US',
#    'sunrise': 1561812547,
#    'sunset': 1561864508},
#   'timezone': -25200,
#   'id': 5392952,
#   'name': 'Santa Barbara',
#   'cod': 200},
#  {'coord': {'lon': -121.49, 'lat': 38.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 22.21,
#    'pressure': 1017,
#    'humidity': 56,
#    'temp_min': 19,
#    'temp_max': 25.56},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 10},
#   'clouds': {'all': 1},
#   'dt': 1561827312,
#   'sys': {'type': 1,
#    'id': 3933,
#    'message': 0.009,
#    'country': 'US',
#    'sunrise': 1561812256,
#    'sunset': 1561865658},
#   'timezone': -25200,
#   'id': 5389489,
#   'name': 'Sacramento',
#   'cod': 200},
#  {'coord': {'lon': -70.25, 'lat': 43.66},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 25.04,
#    'pressure': 1014,
#    'humidity': 64,
#    'temp_min': 23,
#    'temp_max': 26.67},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 200},
#   'clouds': {'all': 75},
#   'dt': 1561827141,
#   'sys': {'type': 1,
#    'id': 5454,
#    'message': 0.0095,
#    'country': 'US',
#    'sunrise': 1561798923,
#    'sunset': 1561854392},
#   'timezone': -14400,
#   'id': 4975802,
#   'name': 'Portland',
#   'cod': 200},
#  {'coord': {'lon': -80.05, 'lat': 26.72},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'},
#    {'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'}],
#   'base': 'stations',
#   'main': {'temp': 24.25,
#    'pressure': 1021,
#    'humidity': 100,
#    'temp_min': 23,
#    'temp_max': 25.56},
#   'visibility': 8047,
#   'wind': {'speed': 3.1, 'deg': 90},
#   'rain': {'1h': 3.3},
#   'clouds': {'all': 1},
#   'dt': 1561827377,
#   'sys': {'type': 1,
#    'id': 4044,
#    'message': 0.0101,
#    'country': 'US',
#    'sunrise': 1561804166,
#    'sunset': 1561853854},
#   'timezone': -14400,
#   'id': 4177887,
#   'name': 'West Palm Beach',
#   'cod': 200},
#  {'coord': {'lon': -122.2, 'lat': 47.97},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.67,
#    'pressure': 1022,
#    'humidity': 72,
#    'temp_min': 15.56,
#    'temp_max': 20},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 340},
#   'clouds': {'all': 1},
#   'dt': 1561827378,
#   'sys': {'type': 1,
#    'id': 5301,
#    'message': 0.0117,
#    'country': 'US',
#    'sunrise': 1561810333,
#    'sunset': 1561867922},
#   'timezone': -25200,
#   'id': 5793933,
#   'name': 'Everett',
#   'cod': 200},
#  {'coord': {'lon': -122.44, 'lat': 47.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.06,
#    'pressure': 1022,
#    'humidity': 59,
#    'temp_min': 16,
#    'temp_max': 19},
#   'visibility': 16093,
#   'wind': {'speed': 1.72, 'deg': 2.661},
#   'clouds': {'all': 1},
#   'dt': 1561827215,
#   'sys': {'type': 1,
#    'id': 5366,
#    'message': 0.0107,
#    'country': 'US',
#    'sunrise': 1561810583,
#    'sunset': 1561867787},
#   'timezone': -25200,
#   'id': 5812944,
#   'name': 'Tacoma',
#   'cod': 200},
#  {'coord': {'lon': -70.25, 'lat': 43.66},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 25.04,
#    'pressure': 1014,
#    'humidity': 64,
#    'temp_min': 23,
#    'temp_max': 26.67},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 200},
#   'clouds': {'all': 75},
#   'dt': 1561827141,
#   'sys': {'type': 1,
#    'id': 5454,
#    'message': 0.0095,
#    'country': 'US',
#    'sunrise': 1561798923,
#    'sunset': 1561854392},
#   'timezone': -14400,
#   'id': 4975802,
#   'name': 'Portland',
#   'cod': 200},
#  {'coord': {'lon': -76.61, 'lat': 39.29},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 32.87,
#    'pressure': 1019,
#    'humidity': 55,
#    'temp_min': 31.11,
#    'temp_max': 34.44},
#   'visibility': 16093,
#   'wind': {'speed': 5.1, 'deg': 260, 'gust': 7.2},
#   'rain': {'3h': 4.438},
#   'clouds': {'all': 70},
#   'dt': 1561827083,
#   'sys': {'type': 1,
#    'id': 4115,
#    'message': 0.0112,
#    'country': 'US',
#    'sunrise': 1561801349,
#    'sunset': 1561855020},
#   'timezone': -14400,
#   'id': 4347778,
#   'name': 'Baltimore',
#   'cod': 200},
#  {'coord': {'lon': -90.07, 'lat': 29.95},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 29.51,
#    'pressure': 1020,
#    'humidity': 62,
#    'temp_min': 28,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 2.1},
#   'clouds': {'all': 40},
#   'dt': 1561827378,
#   'sys': {'type': 1,
#    'id': 2837,
#    'message': 0.0092,
#    'country': 'US',
#    'sunrise': 1561806120,
#    'sunset': 1561856711},
#   'timezone': -18000,
#   'id': 4335045,
#   'name': 'New Orleans',
#   'cod': 200},
#  {'coord': {'lon': -80.84, 'lat': 35.23},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 31.26,
#    'pressure': 1023,
#    'humidity': 48,
#    'temp_min': 30,
#    'temp_max': 33.33},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 220},
#   'clouds': {'all': 1},
#   'dt': 1561827315,
#   'sys': {'type': 1,
#    'id': 4538,
#    'message': 0.011,
#    'country': 'US',
#    'sunrise': 1561803085,
#    'sunset': 1561855315},
#   'timezone': -14400,
#   'id': 4460243,
#   'name': 'Charlotte',
#   'cod': 200},
#  {'coord': {'lon': -93.27, 'lat': 44.98},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 28.78,
#    'pressure': 1019,
#    'humidity': 61,
#    'temp_min': 27.22,
#    'temp_max': 30.56},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 160},
#   'clouds': {'all': 1},
#   'dt': 1561827127,
#   'sys': {'type': 1,
#    'id': 5829,
#    'message': 0.0108,
#    'country': 'US',
#    'sunrise': 1561804146,
#    'sunset': 1561860221},
#   'timezone': -18000,
#   'id': 5037649,
#   'name': 'Minneapolis',
#   'cod': 200},
#  {'coord': {'lon': -123.1, 'lat': 44.05},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 16.75,
#    'pressure': 1021,
#    'humidity': 67,
#    'temp_min': 15,
#    'temp_max': 18.33},
#   'visibility': 16093,
#   'wind': {'speed': 1.84, 'deg': 30.308},
#   'clouds': {'all': 20},
#   'dt': 1561827166,
#   'sys': {'type': 1,
#    'id': 4018,
#    'message': 0.01,
#    'country': 'US',
#    'sunrise': 1561811523,
#    'sunset': 1561867164},
#   'timezone': -25200,
#   'id': 5725846,
#   'name': 'Eugene',
#   'cod': 200},
#  {'coord': {'lon': -117.16, 'lat': 32.72},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 21.92,
#    'pressure': 1017,
#    'humidity': 82,
#    'temp_min': 18.89,
#    'temp_max': 25},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 330},
#   'clouds': {'all': 75},
#   'dt': 1561827088,
#   'sys': {'type': 1,
#    'id': 5771,
#    'message': 0.0095,
#    'country': 'US',
#    'sunrise': 1561812208,
#    'sunset': 1561863628},
#   'timezone': -25200,
#   'id': 5391811,
#   'name': 'San Diego',
#   'cod': 200},
#  {'coord': {'lon': -122.48, 'lat': 48.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.4,
#    'pressure': 1021,
#    'humidity': 77,
#    'temp_min': 14.44,
#    'temp_max': 20},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 330},
#   'clouds': {'all': 1},
#   'dt': 1561827365,
#   'sys': {'type': 1,
#    'id': 5232,
#    'message': 0.0123,
#    'country': 'US',
#    'sunrise': 1561810183,
#    'sunset': 1561868206},
#   'timezone': -25200,
#   'id': 5786899,
#   'name': 'Bellingham',
#   'cod': 200},
#  {'coord': {'lon': -84.39, 'lat': 33.75},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 29.21,
#    'pressure': 1022,
#    'humidity': 52,
#    'temp_min': 27.22,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 130},
#   'clouds': {'all': 75},
#   'dt': 1561827292,
#   'sys': {'type': 1,
#    'id': 3730,
#    'message': 0.0089,
#    'country': 'US',
#    'sunrise': 1561804179,
#    'sunset': 1561855925},
#   'timezone': -14400,
#   'id': 4180439,
#   'name': 'Atlanta',
#   'cod': 200},
#  {'coord': {'lon': -104.98, 'lat': 39.74},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 31.05,
#    'pressure': 1023,
#    'humidity': 27,
#    'temp_min': 27.78,
#    'temp_max': 33.89},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 350},
#   'clouds': {'all': 1},
#   'dt': 1561827109,
#   'sys': {'type': 1,
#    'id': 3958,
#    'message': 0.0108,
#    'country': 'US',
#    'sunrise': 1561808074,
#    'sunset': 1561861915},
#   'timezone': -21600,
#   'id': 5419384,
#   'name': 'Denver',
#   'cod': 200},
#  {'coord': {'lon': -93.1, 'lat': 44.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 28.8,
#    'pressure': 1019,
#    'humidity': 61,
#    'temp_min': 27.22,
#    'temp_max': 30.56},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 160},
#   'clouds': {'all': 1},
#   'dt': 1561827188,
#   'sys': {'type': 1,
#    'id': 5829,
#    'message': 0.0096,
#    'country': 'US',
#    'sunrise': 1561804112,
#    'sunset': 1561860173},
#   'timezone': -18000,
#   'id': 5045360,
#   'name': 'Saint Paul',
#   'cod': 200},
#  {'coord': {'lon': -86.8, 'lat': 33.52},
#   'weather': [{'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'}],
#   'base': 'stations',
#   'main': {'temp': 29.41,
#    'pressure': 1022,
#    'humidity': 79,
#    'temp_min': 27,
#    'temp_max': 32},
#   'visibility': 16093,
#   'wind': {'speed': 2.1},
#   'clouds': {'all': 75},
#   'dt': 1561827274,
#   'sys': {'type': 1,
#    'id': 5371,
#    'message': 0.0085,
#    'country': 'US',
#    'sunrise': 1561804794,
#    'sunset': 1561856467},
#   'timezone': -18000,
#   'id': 4049979,
#   'name': 'Birmingham',
#   'cod': 200},
#  {'coord': {'lon': -82.55, 'lat': 35.6},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 28.91,
#    'pressure': 1024,
#    'humidity': 42,
#    'temp_min': 25,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 230},
#   'clouds': {'all': 1},
#   'dt': 1561827111,
#   'sys': {'type': 1,
#    'id': 4124,
#    'message': 0.0092,
#    'country': 'US',
#    'sunrise': 1561803434,
#    'sunset': 1561855787},
#   'timezone': -14400,
#   'id': 4453066,
#   'name': 'Asheville',
#   'cod': 200},
#  {'coord': {'lon': -81.87, 'lat': 26.64},
#   'weather': [{'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'},
#    {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 27.95,
#    'pressure': 1019,
#    'humidity': 70,
#    'temp_min': 24.44,
#    'temp_max': 30.56},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 130},
#   'clouds': {'all': 1},
#   'dt': 1561827275,
#   'sys': {'type': 1,
#    'id': 4122,
#    'message': 0.0083,
#    'country': 'US',
#    'sunrise': 1561804614,
#    'sunset': 1561854280},
#   'timezone': -14400,
#   'id': 4155995,
#   'name': 'Fort Myers',
#   'cod': 200},
#  {'coord': {'lon': -86.16, 'lat': 39.77},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 30.32,
#    'pressure': 1021,
#    'humidity': 58,
#    'temp_min': 28.89,
#    'temp_max': 31.67},
#   'visibility': 16093,
#   'wind': {'speed': 4.6, 'deg': 270},
#   'clouds': {'all': 40},
#   'dt': 1561827341,
#   'sys': {'type': 1,
#    'id': 4345,
#    'message': 0.0075,
#    'country': 'US',
#    'sunrise': 1561803550,
#    'sunset': 1561857404},
#   'timezone': -14400,
#   'id': 4259418,
#   'name': 'Indianapolis',
#   'cod': 200},
#  {'coord': {'lon': -81.66, 'lat': 30.33},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 30.82,
#    'pressure': 1021,
#    'humidity': 49,
#    'temp_min': 28.89,
#    'temp_max': 32.78},
#   'visibility': 8047,
#   'wind': {'speed': 2.6, 'deg': 190},
#   'clouds': {'all': 20},
#   'dt': 1561827097,
#   'sys': {'type': 1,
#    'id': 4349,
#    'message': 0.0097,
#    'country': 'US',
#    'sunrise': 1561804046,
#    'sunset': 1561854748},
#   'timezone': -14400,
#   'id': 4160021,
#   'name': 'Jacksonville',
#   'cod': 200},
#  {'coord': {'lon': -78.88, 'lat': 42.89},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 26.46,
#    'pressure': 1017,
#    'humidity': 65,
#    'temp_min': 23.89,
#    'temp_max': 28.33},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 240, 'gust': 8.7},
#   'clouds': {'all': 40},
#   'dt': 1561827379,
#   'sys': {'type': 1,
#    'id': 3518,
#    'message': 0.0072,
#    'country': 'US',
#    'sunrise': 1561801165,
#    'sunset': 1561856294},
#   'timezone': -14400,
#   'id': 5110629,
#   'name': 'Buffalo',
#   'cod': 200},
#  {'coord': {'lon': -122.89, 'lat': 47.05},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.06,
#    'pressure': 1022,
#    'humidity': 77,
#    'temp_min': 14,
#    'temp_max': 19.44},
#   'visibility': 16093,
#   'wind': {'speed': 1.4, 'deg': 44.971},
#   'clouds': {'all': 1},
#   'dt': 1561827379,
#   'sys': {'type': 1,
#    'id': 6022,
#    'message': 0.0132,
#    'country': 'US',
#    'sunrise': 1561810744,
#    'sunset': 1561867843},
#   'timezone': -25200,
#   'id': 5805687,
#   'name': 'Olympia',
#   'cod': 200},
#  {'coord': {'lon': 30.32, 'lat': 59.94},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 16.89,
#    'pressure': 1005,
#    'humidity': 55,
#    'temp_min': 16.67,
#    'temp_max': 17.22},
#   'visibility': 10000,
#   'wind': {'speed': 7, 'deg': 280},
#   'clouds': {'all': 0},
#   'dt': 1561827379,
#   'sys': {'type': 1,
#    'id': 8926,
#    'message': 0.0067,
#    'country': 'RU',
#    'sunrise': 1561768751,
#    'sunset': 1561836284},
#   'timezone': 10800,
#   'id': 498817,
#   'name': 'Saint Petersburg',
#   'cod': 200},
#  {'coord': {'lon': -97.74, 'lat': 30.27},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 31.1,
#    'pressure': 1020,
#    'humidity': 55,
#    'temp_min': 29.44,
#    'temp_max': 32.78},
#   'visibility': 11265,
#   'wind': {'speed': 2.26, 'deg': 151.377},
#   'clouds': {'all': 1},
#   'dt': 1561827363,
#   'sys': {'type': 1,
#    'id': 3931,
#    'message': 0.0277,
#    'country': 'US',
#    'sunrise': 1561807914,
#    'sunset': 1561858598},
#   'timezone': -18000,
#   'id': 4671654,
#   'name': 'Austin',
#   'cod': 200},
#  {'coord': {'lon': -92.46, 'lat': 44.02},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 29.13,
#    'pressure': 1020,
#    'humidity': 65,
#    'temp_min': 27,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 140},
#   'clouds': {'all': 1},
#   'dt': 1561827379,
#   'sys': {'type': 1,
#    'id': 6051,
#    'message': 0.0091,
#    'country': 'US',
#    'sunrise': 1561804174,
#    'sunset': 1561859804},
#   'timezone': -18000,
#   'id': 5043473,
#   'name': 'Rochester',
#   'cod': 200},
#  {'coord': {'lon': -81.38, 'lat': 28.54},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'},
#    {'id': 202,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm with heavy rain',
#     'icon': '11d'},
#    {'id': 300,
#     'main': 'Drizzle',
#     'description': 'light intensity drizzle',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 28.77,
#    'pressure': 1021,
#    'humidity': 62,
#    'temp_min': 23,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 8.2, 'deg': 120},
#   'rain': {'1h': 5.46},
#   'clouds': {'all': 75},
#   'dt': 1561827280,
#   'sys': {'type': 1,
#    'id': 5234,
#    'message': 0.0103,
#    'country': 'US',
#    'sunrise': 1561804235,
#    'sunset': 1561854424},
#   'timezone': -14400,
#   'id': 4167147,
#   'name': 'Orlando',
#   'cod': 200},
#  {'coord': {'lon': -89.59, 'lat': 40.69},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 30.05,
#    'pressure': 1019,
#    'humidity': 66,
#    'temp_min': 27.78,
#    'temp_max': 32.22},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 230},
#   'clouds': {'all': 40},
#   'dt': 1561827244,
#   'sys': {'type': 1,
#    'id': 3561,
#    'message': 0.0094,
#    'country': 'US',
#    'sunrise': 1561804193,
#    'sunset': 1561858407},
#   'timezone': -18000,
#   'id': 4905687,
#   'name': 'Peoria',
#   'cod': 200},
#  {'coord': {'lon': -81.69, 'lat': 41.51},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 29.18,
#    'pressure': 1020,
#    'humidity': 54,
#    'temp_min': 26.67,
#    'temp_max': 31.67},
#   'visibility': 16093,
#   'wind': {'speed': 6.2, 'deg': 270, 'gust': 8.7},
#   'clouds': {'all': 40},
#   'dt': 1561827169,
#   'sys': {'type': 1,
#    'id': 5396,
#    'message': 0.0093,
#    'country': 'US',
#    'sunrise': 1561802130,
#    'sunset': 1561856677},
#   'timezone': -14400,
#   'id': 5150529,
#   'name': 'Cleveland',
#   'cod': 200},
#  {'coord': {'lon': -78.64, 'lat': 35.78},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 32.95,
#    'pressure': 1021,
#    'humidity': 49,
#    'temp_min': 31,
#    'temp_max': 35},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 300},
#   'clouds': {'all': 40},
#   'dt': 1561827380,
#   'sys': {'type': 1,
#    'id': 6072,
#    'message': 0.0084,
#    'country': 'US',
#    'sunrise': 1561802464,
#    'sunset': 1561854879},
#   'timezone': -14400,
#   'id': 4487042,
#   'name': 'Raleigh',
#   'cod': 200},
#  {'coord': {'lon': -97.11, 'lat': 32.74},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 32.84,
#    'pressure': 1020,
#    'humidity': 43,
#    'temp_min': 31,
#    'temp_max': 35},
#   'visibility': 16093,
#   'wind': {'speed': 3.6, 'deg': 270},
#   'clouds': {'all': 5},
#   'dt': 1561827349,
#   'sys': {'type': 1,
#    'id': 4249,
#    'message': 0.0121,
#    'country': 'US',
#    'sunrise': 1561807391,
#    'sunset': 1561858819},
#   'timezone': -18000,
#   'id': 4671240,
#   'name': 'Arlington',
#   'cod': 200},
#  {'coord': {'lon': 1.08, 'lat': 36.43},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 25.6,
#    'pressure': 1010.9,
#    'humidity': 65,
#    'temp_min': 25.6,
#    'temp_max': 25.6,
#    'sea_level': 1010.9,
#    'grnd_level': 1002.84},
#   'wind': {'speed': 9.14, 'deg': 67.75},
#   'clouds': {'all': 0},
#   'dt': 1561827380,
#   'sys': {'message': 0.0073,
#    'country': 'DZ',
#    'sunrise': 1561783215,
#    'sunset': 1561835857},
#   'timezone': 3600,
#   'id': 2481207,
#   'name': 'Saint Louis',
#   'cod': 200},
#  {'coord': {'lon': -87.92, 'lat': 43.03},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 27.99,
#    'pressure': 1020,
#    'humidity': 65,
#    'temp_min': 25.56,
#    'temp_max': 30},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 170},
#   'clouds': {'all': 75},
#   'dt': 1561827167,
#   'sys': {'type': 1,
#    'id': 4013,
#    'message': 0.0094,
#    'country': 'US',
#    'sunrise': 1561803304,
#    'sunset': 1561858494},
#   'timezone': -18000,
#   'id': 5263045,
#   'name': 'Milwaukee',
#   'cod': 200},
#  {'coord': {'lon': -86.77, 'lat': 36.16},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 30.54,
#    'pressure': 1021,
#    'humidity': 58,
#    'temp_min': 28.89,
#    'temp_max': 32.78},
#   'visibility': 8047,
#   'wind': {'speed': 0.66, 'deg': 249.728},
#   'clouds': {'all': 40},
#   'dt': 1561827349,
#   'sys': {'type': 1,
#    'id': 4609,
#    'message': 0.0079,
#    'country': 'US',
#    'sunrise': 1561804351,
#    'sunset': 1561856895},
#   'timezone': -18000,
#   'id': 4644585,
#   'name': 'Nashville',
#   'cod': 200},
#  {'coord': {'lon': -82.46, 'lat': 27.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 31.04,
#    'pressure': 1019,
#    'humidity': 58,
#    'temp_min': 29.44,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 110},
#   'clouds': {'all': 1},
#   'dt': 1561827182,
#   'sys': {'type': 1,
#    'id': 3654,
#    'message': 0.0147,
#    'country': 'US',
#    'sunrise': 1561804576,
#    'sunset': 1561854601},
#   'timezone': -14400,
#   'id': 4174757,
#   'name': 'Tampa',
#   'cod': 200},
#  {'coord': {'lon': -75.98, 'lat': 36.85},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 32.36,
#    'pressure': 1020,
#    'humidity': 52,
#    'temp_min': 30.56,
#    'temp_max': 34.44},
#   'visibility': 11265,
#   'wind': {'speed': 1.5, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1561827207,
#   'sys': {'type': 1,
#    'id': 3680,
#    'message': 0.0085,
#    'country': 'US',
#    'sunrise': 1561801642,
#    'sunset': 1561854425},
#   'timezone': -14400,
#   'id': 4791259,
#   'name': 'Virginia Beach',
#   'cod': 200},
#  {'coord': {'lon': -76.15, 'lat': 43.05},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 26.21,
#    'pressure': 1016,
#    'humidity': 61,
#    'temp_min': 24.44,
#    'temp_max': 27.22},
#   'visibility': 16093,
#   'wind': {'speed': 4.6, 'deg': 280},
#   'clouds': {'all': 75},
#   'dt': 1561827086,
#   'sys': {'type': 1,
#    'id': 5965,
#    'message': 0.0103,
#    'country': 'US',
#    'sunrise': 1561800474,
#    'sunset': 1561855674},
#   'timezone': -14400,
#   'id': 5140405,
#   'name': 'Syracuse',
#   'cod': 200},
#  {'coord': {'lon': -84.28, 'lat': 30.44},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 27.97,
#    'pressure': 1021,
#    'humidity': 83,
#    'temp_min': 26,
#    'temp_max': 30},
#   'visibility': 16093,
#   'wind': {'speed': 2.6, 'deg': 130},
#   'clouds': {'all': 75},
#   'dt': 1561827261,
#   'sys': {'type': 1,
#    'id': 2828,
#    'message': 0.0071,
#    'country': 'US',
#    'sunrise': 1561804658,
#    'sunset': 1561855393},
#   'timezone': -14400,
#   'id': 4174715,
#   'name': 'Tallahassee',
#   'cod': 200},
#  {'coord': {'lon': -119.02, 'lat': 35.37},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 23.19,
#    'pressure': 1017,
#    'humidity': 37,
#    'temp_min': 18.89,
#    'temp_max': 26.67},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 300},
#   'clouds': {'all': 1},
#   'dt': 1561827365,
#   'sys': {'type': 1,
#    'id': 3824,
#    'message': 0.0073,
#    'country': 'US',
#    'sunrise': 1561812227,
#    'sunset': 1561864501},
#   'timezone': -25200,
#   'id': 5325738,
#   'name': 'Bakersfield',
#   'cod': 200},
#  {'coord': {'lon': -83.73, 'lat': 42.27},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 28.96,
#    'pressure': 1018,
#    'humidity': 58,
#    'temp_min': 26.67,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 3.6, 'deg': 320},
#   'clouds': {'all': 40},
#   'dt': 1561827285,
#   'sys': {'type': 1,
#    'id': 5219,
#    'message': 0.0093,
#    'country': 'US',
#    'sunrise': 1561802462,
#    'sunset': 1561857325},
#   'timezone': -14400,
#   'id': 4984247,
#   'name': 'Ann Arbor',
#   'cod': 200},
#  {'coord': {'lon': -115.15, 'lat': 36.17},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 30.86,
#    'pressure': 1016,
#    'humidity': 8,
#    'temp_min': 29,
#    'temp_max': 32},
#   'visibility': 16093,
#   'wind': {'speed': 4.39, 'deg': 120.818},
#   'clouds': {'all': 1},
#   'dt': 1561827095,
#   'sys': {'type': 1,
#    'id': 3527,
#    'message': 0.0082,
#    'country': 'US',
#    'sunrise': 1561811163,
#    'sunset': 1561863708},
#   'timezone': -25200,
#   'id': 5506956,
#   'name': 'Las Vegas',
#   'cod': 200},
#  {'coord': {'lon': -84.99, 'lat': 32.46},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 29.23,
#    'pressure': 1022,
#    'humidity': 65,
#    'temp_min': 28,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 190},
#   'clouds': {'all': 90},
#   'dt': 1561827358,
#   'sys': {'type': 1,
#    'id': 5359,
#    'message': 0.0104,
#    'country': 'US',
#    'sunrise': 1561804525,
#    'sunset': 1561855867},
#   'timezone': -14400,
#   'id': 4188985,
#   'name': 'Columbus',
#   'cod': 200},
#  {'coord': {'lon': -117.42, 'lat': 47.66},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 17.67,
#    'pressure': 1021,
#    'humidity': 51,
#    'temp_min': 16,
#    'temp_max': 20.56},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 80},
#   'clouds': {'all': 20},
#   'dt': 1561827381,
#   'sys': {'type': 1,
#    'id': 5812,
#    'message': 0.0147,
#    'country': 'US',
#    'sunrise': 1561809269,
#    'sunset': 1561866691},
#   'timezone': -25200,
#   'id': 5811696,
#   'name': 'Spokane',
#   'cod': 200},
#  {'coord': {'lon': -90.05, 'lat': 35.15},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 29.82,
#    'pressure': 1020,
#    'humidity': 58,
#    'temp_min': 28.89,
#    'temp_max': 32.22},
#   'visibility': 16093,
#   'wind': {'speed': 1.5},
#   'clouds': {'all': 1},
#   'dt': 1561827180,
#   'sys': {'type': 1,
#    'id': 4171,
#    'message': 0.0085,
#    'country': 'US',
#    'sunrise': 1561805309,
#    'sunset': 1561857512},
#   'timezone': -18000,
#   'id': 4641239,
#   'name': 'Memphis',
#   'cod': 200},
#  {'coord': {'lon': -81.03, 'lat': 34},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 30.54,
#    'pressure': 1023,
#    'humidity': 51,
#    'temp_min': 29,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 3.33, 'deg': 133.038},
#   'clouds': {'all': 40},
#   'dt': 1561827381,
#   'sys': {'type': 1,
#    'id': 4075,
#    'message': 0.0188,
#    'country': 'US',
#    'sunrise': 1561803332,
#    'sunset': 1561855159},
#   'timezone': -14400,
#   'id': 4575352,
#   'name': 'Columbia',
#   'cod': 200},
#  {'coord': {'lon': -123.03, 'lat': 44.94},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.41,
#    'pressure': 1021,
#    'humidity': 67,
#    'temp_min': 15.56,
#    'temp_max': 19.44},
#   'visibility': 16093,
#   'wind': {'speed': 1.76, 'deg': 69.68},
#   'clouds': {'all': 1},
#   'dt': 1561827184,
#   'sys': {'type': 1,
#    'id': 5858,
#    'message': 0.0117,
#    'country': 'US',
#    'sunrise': 1561811300,
#    'sunset': 1561867353},
#   'timezone': -25200,
#   'id': 5750162,
#   'name': 'Salem',
#   'cod': 200},
#  {'coord': {'lon': -85.14, 'lat': 41.08},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 30.27,
#    'pressure': 1020,
#    'humidity': 38,
#    'temp_min': 28,
#    'temp_max': 32},
#   'wind': {'speed': 5.1, 'deg': 290},
#   'clouds': {'all': 40},
#   'dt': 1561827231,
#   'sys': {'type': 1,
#    'id': 6187,
#    'message': 0.0086,
#    'country': 'US',
#    'sunrise': 1561803046,
#    'sunset': 1561857417},
#   'timezone': -14400,
#   'id': 4920423,
#   'name': 'Fort Wayne',
#   'cod': 200},
#  {'coord': {'lon': -84.19, 'lat': 39.76},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 30.62,
#    'pressure': 1021,
#    'humidity': 52,
#    'temp_min': 28.89,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 5.1, 'deg': 260},
#   'clouds': {'all': 40},
#   'dt': 1561827381,
#   'sys': {'type': 1,
#    'id': 5016,
#    'message': 0.0132,
#    'country': 'US',
#    'sunrise': 1561803079,
#    'sunset': 1561856929},
#   'timezone': -14400,
#   'id': 4509884,
#   'name': 'Dayton',
#   'cod': 200},
#  {'coord': {'lon': -94.56, 'lat': 39.08},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 31.63,
#    'pressure': 1018,
#    'humidity': 59,
#    'temp_min': 30,
#    'temp_max': 33.33},
#   'visibility': 16093,
#   'wind': {'speed': 2.6},
#   'clouds': {'all': 20},
#   'dt': 1561827303,
#   'sys': {'type': 1,
#    'id': 4903,
#    'message': 0.0156,
#    'country': 'US',
#    'sunrise': 1561805698,
#    'sunset': 1561859288},
#   'timezone': -18000,
#   'id': 4393217,
#   'name': 'Kansas City',
#   'cod': 200},
#  {'coord': {'lon': -97.33, 'lat': 32.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 32.54,
#    'pressure': 1019,
#    'humidity': 55,
#    'temp_min': 30.56,
#    'temp_max': 34.44},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 260},
#   'clouds': {'all': 1},
#   'dt': 1561827100,
#   'sys': {'type': 1,
#    'id': 4149,
#    'message': 0.0114,
#    'country': 'US',
#    'sunrise': 1561807442,
#    'sunset': 1561858873},
#   'timezone': -18000,
#   'id': 4691930,
#   'name': 'Fort Worth',
#   'cod': 200},
#  {'coord': {'lon': -94.16, 'lat': 36.06},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 29.4,
#    'pressure': 1021,
#    'humidity': 74,
#    'temp_min': 27.78,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 110},
#   'clouds': {'all': 40},
#   'dt': 1561827091,
#   'sys': {'type': 1,
#    'id': 5695,
#    'message': 0.0068,
#    'country': 'US',
#    'sunrise': 1561806143,
#    'sunset': 1561858651},
#   'timezone': -18000,
#   'id': 4110486,
#   'name': 'Fayetteville',
#   'cod': 200},
#  {'coord': {'lon': -123.14, 'lat': 49.16},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.21,
#    'pressure': 1021,
#    'humidity': 77,
#    'temp_min': 15,
#    'temp_max': 19.44},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 330},
#   'clouds': {'all': 1},
#   'dt': 1561827135,
#   'sys': {'type': 1,
#    'id': 5232,
#    'message': 0.0122,
#    'country': 'CA',
#    'sunrise': 1561810224,
#    'sunset': 1561868482},
#   'timezone': -25200,
#   'id': 6122085,
#   'name': 'Richmond',
#   'cod': 200},
#  {'coord': {'lon': -79.79, 'lat': 36.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 31.81,
#    'pressure': 1022,
#    'humidity': 52,
#    'temp_min': 30,
#    'temp_max': 33.89},
#   'wind': {'speed': 3.63, 'deg': 240.484},
#   'clouds': {'all': 1},
#   'dt': 1561827382,
#   'sys': {'type': 1,
#    'id': 5842,
#    'message': 0.0095,
#    'country': 'US',
#    'sunrise': 1561802691,
#    'sunset': 1561855204},
#   'timezone': -14400,
#   'id': 4469146,
#   'name': 'Greensboro',
#   'cod': 200},
# ...
#    'id': 4294,
#    'message': 0.0099,
#    'country': 'US',
#    'sunrise': 1561810874,
#    'sunset': 1561862523},
#   'timezone': -25200,
#   'id': 5308655,
#   'name': 'Phoenix',
#   'cod': 200},
#  {'coord': {'lon': -82.33, 'lat': 29.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 31.29,
#    'pressure': 1020,
#    'humidity': 62,
#    'temp_min': 30,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 250},
#   'clouds': {'all': 1},
#   'dt': 1561827382,
#   'sys': {'type': 1,
#    'id': 2924,
#    'message': 0.0082,
#    'country': 'US',
#    'sunrise': 1561804305,
#    'sunset': 1561854810},
#   'timezone': -14400,
#   'id': 4156404,
#   'name': 'Gainesville',
#   'cod': 200},
#  {'coord': {'lon': -85.67, 'lat': 42.96},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 28.3,
#    'pressure': 1019,
#    'humidity': 51,
#    'temp_min': 26.67,
#    'temp_max': 30},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 350},
#   'clouds': {'all': 1},
#   'dt': 1561827326,
#   'sys': {'type': 1,
#    'id': 4090,
#    'message': 0.0081,
#    'country': 'US',
#    'sunrise': 1561802780,
#    'sunset': 1561857939},
#   'timezone': -14400,
#   'id': 4994358,
#   'name': 'Grand Rapids',
#   'cod': 200},
#  {'coord': {'lon': -110.93, 'lat': 32.22},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 36.42,
#    'pressure': 1014,
#    'humidity': 9,
#    'temp_min': 34,
#    'temp_max': 38.33},
#   'visibility': 16093,
#   'wind': {'speed': 1.62, 'deg': 260.805},
#   'clouds': {'all': 1},
#   'dt': 1561827154,
#   'sys': {'type': 1,
#    'id': 3342,
#    'message': 0.0098,
#    'country': 'US',
#    'sunrise': 1561810789,
#    'sunset': 1561862055},
#   'timezone': -25200,
#   'id': 5318313,
#   'name': 'Tucson',
#   'cod': 200},
#  {'coord': {'lon': -89.38, 'lat': 43.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 28.6,
#    'pressure': 1020,
#    'humidity': 62,
#    'temp_min': 27,
#    'temp_max': 30},
#   'visibility': 16093,
#   'wind': {'speed': 2.6, 'deg': 120},
#   'clouds': {'all': 1},
#   'dt': 1561826786,
#   'sys': {'type': 1,
#    'id': 3551,
#    'message': 0.0079,
#    'country': 'US',
#    'sunrise': 1561803646,
#    'sunset': 1561858853},
#   'timezone': -18000,
#   'id': 5261457,
#   'name': 'Madison',
#   'cod': 200},
#  {'coord': {'lon': -85.31, 'lat': 35.05},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 29.52,
#    'pressure': 1022,
#    'humidity': 55,
#    'temp_min': 27.78,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 80},
#   'clouds': {'all': 20},
#   'dt': 1561827244,
#   'sys': {'type': 1,
#    'id': 5765,
#    'message': 0.0092,
#    'country': 'US',
#    'sunrise': 1561804188,
#    'sunset': 1561856357},
#   'timezone': -14400,
#   'id': 4612862,
#   'name': 'Chattanooga',
#   'cod': 200},
#  {'coord': {'lon': -119.78, 'lat': 36.74},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 23.37,
#    'pressure': 1017,
#    'humidity': 38,
#    'temp_min': 21,
#    'temp_max': 25.56},
#   'visibility': 16093,
#   'wind': {'speed': 1.5},
#   'clouds': {'all': 1},
#   'dt': 1561827083,
#   'sys': {'type': 1,
#    'id': 4068,
#    'message': 0.0078,
#    'country': 'US',
#    'sunrise': 1561812176,
#    'sunset': 1561864917},
#   'timezone': -25200,
#   'id': 5350937,
#   'name': 'Fresno',
#   'cod': 200},
#  {'coord': {'lon': -97.34, 'lat': 37.69},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 32.71,
#    'pressure': 1019,
#    'humidity': 58,
#    'temp_min': 31,
#    'temp_max': 35},
#   'visibility': 16093,
#   'wind': {'speed': 2.6, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1561827191,
#   'sys': {'type': 1,
#    'id': 3408,
#    'message': 0.0085,
#    'country': 'US',
#    'sunrise': 1561806621,
#    'sunset': 1561859700},
#   'timezone': -18000,
#   'id': 4281730,
#   'name': 'Wichita',
#   'cod': 200},
#  {'coord': {'lon': -111.89, 'lat': 40.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 23.46,
#    'pressure': 1022,
#    'humidity': 37,
#    'temp_min': 21,
#    'temp_max': 26.11},
#   'visibility': 16093,
#   'wind': {'speed': 1.2, 'deg': 180.956},
#   'clouds': {'all': 1},
#   'dt': 1561827108,
#   'sys': {'type': 1,
#    'id': 6116,
#    'message': 0.0125,
#    'country': 'US',
#    'sunrise': 1561809530,
#    'sunset': 1561863775},
#   'timezone': -21600,
#   'id': 5780993,
#   'name': 'Salt Lake City',
#   'cod': 200},
#  {'coord': {'lon': -83.06, 'lat': 42.35},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 29.02,
#    'pressure': 1019,
#    'humidity': 45,
#    'temp_min': 26.67,
#    'temp_max': 31},
#   'visibility': 16093,
#   'wind': {'speed': 5.1, 'deg': 310},
#   'clouds': {'all': 75},
#   'dt': 1561827330,
#   'sys': {'type': 1,
#    'id': 6182,
#    'message': 0.0077,
#    'country': 'US',
#    'sunrise': 1561802284,
#    'sunset': 1561857181},
#   'timezone': -14400,
#   'id': 4990729,
#   'name': 'Detroit',
#   'cod': 200},
#  {'coord': {'lon': -95.99, 'lat': 36.16},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 31.97,
#    'pressure': 1019,
#    'humidity': 55,
#    'temp_min': 31,
#    'temp_max': 33.33},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 120},
#   'clouds': {'all': 40},
#   'dt': 1561827323,
#   'sys': {'type': 1,
#    'id': 5251,
#    'message': 0.0079,
#    'country': 'US',
#    'sunrise': 1561806565,
#    'sunset': 1561859108},
#   'timezone': -18000,
#   'id': 4553433,
#   'name': 'Tulsa',
#   'cod': 200},
#  {'coord': {'lon': -84.51, 'lat': 39.1},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 30.78,
#    'pressure': 1021,
#    'humidity': 52,
#    'temp_min': 28.89,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 5.1, 'deg': 260},
#   'clouds': {'all': 40},
#   'dt': 1561827107,
#   'sys': {'type': 1,
#    'id': 5016,
#    'message': 0.0131,
#    'country': 'US',
#    'sunrise': 1561803281,
#    'sunset': 1561856880},
#   'timezone': -14400,
#   'id': 4508722,
#   'name': 'Cincinnati',
#   'cod': 200},
#  {'coord': {'lon': -101.86, 'lat': 33.58},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 29.34,
#    'pressure': 1023,
#    'humidity': 42,
#    'temp_min': 28,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 220},
#   'clouds': {'all': 1},
#   'dt': 1561827256,
#   'sys': {'type': 1,
#    'id': 5443,
#    'message': 0.0063,
#    'country': 'US',
#    'sunrise': 1561808400,
#    'sunset': 1561860091},
#   'timezone': -18000,
#   'id': 5525577,
#   'name': 'Lubbock',
#   'cod': 200},
#  {'coord': {'lon': -93.6, 'lat': 41.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 30.51,
#    'pressure': 1018,
#    'humidity': 74,
#    'temp_min': 29,
#    'temp_max': 32.22},
#   'visibility': 14484,
#   'wind': {'speed': 2.6, 'deg': 190},
#   'clouds': {'all': 1},
#   'dt': 1561827383,
#   'sys': {'type': 1,
#    'id': 4515,
#    'message': 0.0089,
#    'country': 'US',
#    'sunrise': 1561804973,
#    'sunset': 1561859552},
#   'timezone': -18000,
#   'id': 4853828,
#   'name': 'Des Moines',
#   'cod': 200},
#  {'coord': {'lon': -95.37, 'lat': 29.76},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 30.42,
#    'pressure': 1019,
#    'humidity': 70,
#    'temp_min': 28.89,
#    'temp_max': 32.22},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 300},
#   'clouds': {'all': 40},
#   'dt': 1561827237,
#   'sys': {'type': 1,
#    'id': 3370,
#    'message': 0.0107,
#    'country': 'US',
#    'sunrise': 1561807420,
#    'sunset': 1561857955},
#   'timezone': -18000,
#   'id': 4699066,
#   'name': 'Houston',
#   'cod': 200},
#  {'coord': {'lon': -97.52, 'lat': 35.47},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 33.24,
#    'pressure': 1019,
#    'humidity': 38,
#    'temp_min': 31,
#    'temp_max': 35.56},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1561827094,
#   'sys': {'type': 1,
#    'id': 5628,
#    'message': 0.0098,
#    'country': 'US',
#    'sunrise': 1561807049,
#    'sunset': 1561859358},
#   'timezone': -18000,
#   'id': 4544349,
#   'name': 'Oklahoma City',
#   'cod': 200},
#  {'coord': {'lon': -83.92, 'lat': 35.96},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 29.14,
#    'pressure': 1023,
#    'humidity': 58,
#    'temp_min': 27.22,
#    'temp_max': 31.11},
#   'visibility': 16093,
#   'wind': {'speed': 0.89, 'deg': 193.585},
#   'clouds': {'all': 1},
#   'dt': 1561827356,
#   'sys': {'type': 1,
#    'id': 3818,
#    'message': 0.0081,
#    'country': 'US',
#    'sunrise': 1561803701,
#    'sunset': 1561856177},
#   'timezone': -14400,
#   'id': 4634946,
#   'name': 'Knoxville',
#   'cod': 200},
#  {'coord': {'lon': -72.59, 'lat': 42.1},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 27.33,
#    'pressure': 1014,
#    'humidity': 61,
#    'temp_min': 24,
#    'temp_max': 30.56},
#   'visibility': 16093,
#   'wind': {'speed': 2.6, 'deg': 210},
#   'clouds': {'all': 90},
#   'dt': 1561827125,
#   'sys': {'type': 1,
#    'id': 3598,
#    'message': 0.0138,
#    'country': 'US',
#    'sunrise': 1561799823,
#    'sunset': 1561854616},
#   'timezone': -14400,
#   'id': 4951788,
#   'name': 'Springfield',
#   'cod': 200},
#  {'coord': {'lon': -123.12, 'lat': 49.26},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.1,
#    'pressure': 1021,
#    'humidity': 77,
#    'temp_min': 15,
#    'temp_max': 19.44},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 330},
#   'clouds': {'all': 1},
#   'dt': 1561827210,
#   'sys': {'type': 1,
#    'id': 5232,
#    'message': 0.0105,
#    'country': 'CA',
#    'sunrise': 1561810190,
#    'sunset': 1561868506},
#   'timezone': -25200,
#   'id': 6173331,
#   'name': 'Vancouver',
#   'cod': 200},
#  {'coord': {'lon': -4.02, 'lat': 39.86},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 39.1,
#    'pressure': 1015,
#    'humidity': 12,
#    'temp_min': 38.33,
#    'temp_max': 40},
#   'visibility': 10000,
#   'wind': {'speed': 2.6},
#   'clouds': {'all': 0},
#   'dt': 1561827320,
#   'sys': {'type': 1,
#    'id': 6409,
#    'message': 0.0077,
#    'country': 'ES',
#    'sunrise': 1561783813,
#    'sunset': 1561837708},
#   'timezone': 7200,
#   'id': 2510409,
#   'name': 'Toledo',
#   'cod': 200},
#  {'coord': {'lon': -92.29, 'lat': 34.75},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 28.12,
#    'pressure': 1020,
#    'humidity': 69,
#    'temp_min': 26.67,
#    'temp_max': 29.44},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 50},
#   'clouds': {'all': 75},
#   'dt': 1561827404,
#   'sys': {'type': 1,
#    'id': 4758,
#    'message': 0.0078,
#    'country': 'US',
#    'sunrise': 1561805913,
#    'sunset': 1561857983},
#   'timezone': -18000,
#   'id': 4119403,
#   'name': 'Little Rock',
#   'cod': 200},
#  {'coord': {'lon': -85.76, 'lat': 38.25},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 31.53,
#    'pressure': 1021,
#    'humidity': 55,
#    'temp_min': 29.44,
#    'temp_max': 33.33},
#   'visibility': 16093,
#   'wind': {'speed': 2.13, 'deg': 271.64},
#   'clouds': {'all': 40},
#   'dt': 1561827405,
#   'sys': {'type': 1,
#    'id': 9716,
#    'message': 0.0099,
#    'country': 'US',
#    'sunrise': 1561803739,
#    'sunset': 1561857022},
#   'timezone': -14400,
#   'id': 4299276,
#   'name': 'Louisville',
#   'cod': 200},
#  {'coord': {'lon': -119.81, 'lat': 39.53},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 17.14,
#    'pressure': 1022,
#    'humidity': 20,
#    'temp_min': 13.89,
#    'temp_max': 19.44},
#   'visibility': 16093,
#   'wind': {'speed': 3.1, 'deg': 120},
#   'clouds': {'all': 1},
#   'dt': 1561827139,
#   'sys': {'type': 1,
#    'id': 5724,
#    'message': 0.0101,
#    'country': 'US',
#    'sunrise': 1561811674,
#    'sunset': 1561865433},
#   'timezone': -25200,
#   'id': 5511077,
#   'name': 'Reno',
#   'cod': 200},
#  {'coord': {'lon': -86.59, 'lat': 34.73},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 30.49,
#    'pressure': 1022,
#    'humidity': 62,
#    'temp_min': 28,
#    'temp_max': 32.78},
#   'visibility': 16093,
#   'wind': {'speed': 2.1},
#   'clouds': {'all': 1},
#   'dt': 1561827257,
#   'sys': {'type': 1,
#    'id': 4170,
#    'message': 0.0101,
#    'country': 'US',
#    'sunrise': 1561804548,
#    'sunset': 1561856612},
#   'timezone': -18000,
#   'id': 4068590,
#   'name': 'Huntsville',
#   'cod': 200},
#  {'coord': {'lon': -84.5, 'lat': 38.05},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 30.45,
#    'pressure': 1023,
#    'humidity': 55,
#    'temp_min': 29,
#    'temp_max': 32.22},
#   'visibility': 16093,
#   'wind': {'speed': 2.1, 'deg': 250},
#   'clouds': {'all': 1},
#   'dt': 1561827286,
#   'sys': {'type': 1,
#    'id': 5668,
#    'message': 0.0078,
#    'country': 'US',
#    'sunrise': 1561803473,
#    'sunset': 1561856683},
#   'timezone': -14400,
#   'id': 4297983,
#   'name': 'Lexington',
#   'cod': 200},
#  {'coord': {'lon': -116.2, 'lat': 43.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 20.52,
#    'pressure': 1020,
#    'humidity': 48,
#    'temp_min': 18.89,
#    'temp_max': 21.67},
#   'visibility': 16093,
#   'wind': {'speed': 1.15, 'deg': 303.731},
#   'clouds': {'all': 1},
#   'dt': 1561827210,
#   'sys': {'type': 1,
#    'id': 4829,
#    'message': 0.0077,
#    'country': 'US',
#    'sunrise': 1561809964,
#    'sunset': 1561865411},
#   'timezone': -21600,
#   'id': 5586437,
#   'name': 'Boise',
#   'cod': 200},
#  {'coord': {'lon': -106.49, 'lat': 31.76},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 29.84,
#    'pressure': 1023,
#    'humidity': 35,
#    'temp_min': 28,
#    'temp_max': 31.67},
#   'visibility': 16093,
#   'wind': {'speed': 4.6, 'deg': 100},
#   'clouds': {'all': 1},
#   'dt': 1561827426,
#   'sys': {'type': 1,
#    'id': 3849,
#    'message': 0.0106,
#    'country': 'US',
#    'sunrise': 1561809793,
#    'sunset': 1561860920},
#   'timezone': -21600,
#   'id': 5520993,
#   'name': 'El Paso',
#   'cod': 200},
#  {'coord': {'lon': -71.61, 'lat': -33.58},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 11.28,
#    'pressure': 1021,
#    'humidity': 93,
#    'temp_min': 10,
#    'temp_max': 13},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 320},
#   'clouds': {'all': 75},
#   'dt': 1561827426,
#   'sys': {'type': 1,
#    'id': 8511,
#    'message': 0.0068,
#    'country': 'CL',
#    'sunrise': 1561809088,
#    'sunset': 1561844881},
#   'timezone': -14400,
#   'id': 3872395,
#   'name': 'San Antonio',
#   'cod': 200}]

# %%
# Create an "extracts" object to get the temperature, latitude,
# and longitude in each city
summary = ["main.temp", "coord.lat", "coord.lon"]

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]

weather_data = pd.DataFrame(data, index=cities)
weather_data
# Out:
#                             0      1       2
# (New York,  NY)         31.79  40.73  -73.99
# (San Francisco,  CA)    23.00   1.17  -76.88
# (Honolulu,  HI)         24.56  21.30 -157.86
# (Anchorage,  AK)        19.26  61.22 -149.89
# (Brooklyn,  NY)         29.25  41.44  -81.74
# (Washington,  DC)       33.02  38.90  -77.04
# (Santa Rosa,  CA)        9.08 -36.62  -64.29
# (Charleston,  SC)       30.12  32.79  -79.94
# (Bellevue,  WA)         29.43  50.05   10.19
# (Seattle,  WA)          17.45  47.60 -122.33
# (Berkeley,  CA)         18.24  37.87 -122.27
# (Jersey City,  NJ)      31.84  40.73  -74.08
# (Oakland,  CA)          17.85  37.80 -122.27
# (Boston,  MA)           25.99  42.36  -71.06
# (Hartford,  CT)         28.01  41.76  -72.69
# (Albany,  NY)           25.25  42.65  -73.75
# (Philadelphia,  PA)     32.17  39.95  -75.16
# (Irvine,  CA)           22.77  33.69 -117.83
# (Long Beach,  CA)       29.04  30.35  -89.15
# (Los Angeles,  CA)      22.84  34.05 -118.24
# (Chicago,  IL)          29.52  41.88  -87.62
# (Boulder,  CO)          29.52  40.02 -105.27
# (San Jose,  CA)         26.00  14.25  -87.96
# (Burlington,  VT)       26.30  43.32  -79.80
# (Pittsburgh,  PA)       29.20  40.44  -79.99
# (Miami,  FL)            24.74  25.77  -80.19
# (Santa Barbara,  CA)    22.30  34.42 -119.70
# (Sacramento,  CA)       22.21  38.58 -121.49
# (Portland,  ME)         25.04  43.66  -70.25
# (West Palm Beach,  FL)  24.25  26.72  -80.05
# ...                       ...    ...     ...
# (Dallas,  TX)           32.98  32.78  -96.80
# (Albuquerque,  NM)      29.24  35.08 -106.65
# (Phoenix,  AZ)          37.02  33.45 -112.08
# (Gainesville,  FL)      31.29  29.65  -82.33
# (Grand Rapids,  MI)     28.30  42.96  -85.67
# (Tucson,  AZ)           36.42  32.22 -110.93
# (Madison,  WI)          28.60  43.07  -89.38
# (Chattanooga,  TN)      29.52  35.05  -85.31
# (Fresno,  CA)           23.37  36.74 -119.78
# (Wichita,  KS)          32.71  37.69  -97.34
# (Salt Lake City,  UT)   23.46  40.77 -111.89
# (Detroit,  MI)          29.02  42.35  -83.06
# (Tulsa,  OK)            31.97  36.16  -95.99
# (Cincinnati,  OH)       30.78  39.10  -84.51
# (Lubbock,  TX)          29.34  33.58 -101.86
# (Des Moines,  IA)       30.51  41.59  -93.60
# (Houston,  TX)          30.42  29.76  -95.37
# (Oklahoma City,  OK)    33.24  35.47  -97.52
# (Knoxville,  TN)        29.14  35.96  -83.92
# (Springfield,  MO)      27.33  42.10  -72.59
# (Vancouver,  WA)        17.10  49.26 -123.12
# (Toledo,  OH)           39.10  39.86   -4.02
# (Little Rock,  AR)      28.12  34.75  -92.29
# (Louisville,  KY)       31.53  38.25  -85.76
# (Reno,  NV)             17.14  39.53 -119.81
# (Huntsville,  AL)       30.49  34.73  -86.59
# (Lexington,  KY)        30.45  38.05  -84.50
# (Boise,  ID)            20.52  43.62 -116.20
# (El Paso,  TX)          29.84  31.76 -106.49
# (San Antonio,  TX)      11.28 -33.58  -71.61
#
# [110 rows x 3 columns]

# %%
# BONUS:
column_names = ["Temperature", "Latitude", "Longitude"]
weather_data = pd.DataFrame(data, index=cities, columns=column_names)
weather_data
# Out:
#                         Temperature  Latitude  Longitude
# (New York,  NY)               31.79     40.73     -73.99
# (San Francisco,  CA)          23.00      1.17     -76.88
# (Honolulu,  HI)               24.56     21.30    -157.86
# (Anchorage,  AK)              19.26     61.22    -149.89
# (Brooklyn,  NY)               29.25     41.44     -81.74
# (Washington,  DC)             33.02     38.90     -77.04
# (Santa Rosa,  CA)              9.08    -36.62     -64.29
# (Charleston,  SC)             30.12     32.79     -79.94
# (Bellevue,  WA)               29.43     50.05      10.19
# (Seattle,  WA)                17.45     47.60    -122.33
# (Berkeley,  CA)               18.24     37.87    -122.27
# (Jersey City,  NJ)            31.84     40.73     -74.08
# (Oakland,  CA)                17.85     37.80    -122.27
# (Boston,  MA)                 25.99     42.36     -71.06
# (Hartford,  CT)               28.01     41.76     -72.69
# (Albany,  NY)                 25.25     42.65     -73.75
# (Philadelphia,  PA)           32.17     39.95     -75.16
# (Irvine,  CA)                 22.77     33.69    -117.83
# (Long Beach,  CA)             29.04     30.35     -89.15
# (Los Angeles,  CA)            22.84     34.05    -118.24
# (Chicago,  IL)                29.52     41.88     -87.62
# (Boulder,  CO)                29.52     40.02    -105.27
# (San Jose,  CA)               26.00     14.25     -87.96
# (Burlington,  VT)             26.30     43.32     -79.80
# (Pittsburgh,  PA)             29.20     40.44     -79.99
# (Miami,  FL)                  24.74     25.77     -80.19
# (Santa Barbara,  CA)          22.30     34.42    -119.70
# (Sacramento,  CA)             22.21     38.58    -121.49
# (Portland,  ME)               25.04     43.66     -70.25
# (West Palm Beach,  FL)        24.25     26.72     -80.05
# ...                             ...       ...        ...
# (Dallas,  TX)                 32.98     32.78     -96.80
# (Albuquerque,  NM)            29.24     35.08    -106.65
# (Phoenix,  AZ)                37.02     33.45    -112.08
# (Gainesville,  FL)            31.29     29.65     -82.33
# (Grand Rapids,  MI)           28.30     42.96     -85.67
# (Tucson,  AZ)                 36.42     32.22    -110.93
# (Madison,  WI)                28.60     43.07     -89.38
# (Chattanooga,  TN)            29.52     35.05     -85.31
# (Fresno,  CA)                 23.37     36.74    -119.78
# (Wichita,  KS)                32.71     37.69     -97.34
# (Salt Lake City,  UT)         23.46     40.77    -111.89
# (Detroit,  MI)                29.02     42.35     -83.06
# (Tulsa,  OK)                  31.97     36.16     -95.99
# (Cincinnati,  OH)             30.78     39.10     -84.51
# (Lubbock,  TX)                29.34     33.58    -101.86
# (Des Moines,  IA)             30.51     41.59     -93.60
# (Houston,  TX)                30.42     29.76     -95.37
# (Oklahoma City,  OK)          33.24     35.47     -97.52
# (Knoxville,  TN)              29.14     35.96     -83.92
# (Springfield,  MO)            27.33     42.10     -72.59
# (Vancouver,  WA)              17.10     49.26    -123.12
# (Toledo,  OH)                 39.10     39.86      -4.02
# (Little Rock,  AR)            28.12     34.75     -92.29
# (Louisville,  KY)             31.53     38.25     -85.76
# (Reno,  NV)                   17.14     39.53    -119.81
# (Huntsville,  AL)             30.49     34.73     -86.59
# (Lexington,  KY)              30.45     38.05     -84.50
# (Boise,  ID)                  20.52     43.62    -116.20
# (El Paso,  TX)                29.84     31.76    -106.49
# (San Antonio,  TX)            11.28    -33.58     -71.61
#
# [110 rows x 3 columns]
